# %% [markdown]
# # ICR - Identifying Age-Related Conditions Dataset with TensorFlow Decision Forests

# %% [markdown]
# The goal of this modeling is to predict if a person has one or more of any of three medical conditions or none.
#
# Rough breakdown of notebook contents:
#
# 1. Import libraries
# 2. Load Data
# 3. Data cleaning and preprocessing
# 4. Modeling

# %% [markdown]
# ### Summary of Modeling Choices
#
# <table>
#   <tr>
#     <th style="text-align:left;">Choice</th>
#     <th style="text-align:left;">Details</th>
#   </tr>
#   <tr>
#     <td style="text-align:left;">Data Preprocessing</td>
#     <td style="text-align:left;">training only (no greeks)</td>
#   </tr>
#   <tr>
#     <td style="text-align:left;">Split</td>
#     <td style="text-align:left;">random 80-20 (no time dependency)</td>
#   </tr>
#   <tr>
#     <td style="text-align:left;">Class Imbalance Mitigation</td>
#     <td style="text-align:left;">class weights</td>
#   </tr>
#   <tr>
#     <td style="text-align:left;">Feature Normalization</td>
#     <td style="text-align:left;">Standard Scalar</td>
#   </tr>
#   <tr>
#     <td style="text-align:left;">Metric</td>
#     <td style="text-align:left;">ROC-AUC</td>
#   </tr>
#   <tr>
#     <td style="text-align:left;">Loss</td>
#     <td style="text-align:left;">Binary Crossentropy + Log Loss on Test</td>
#   </tr>
# </table>

# %% [markdown]
# #### Kaggle Competition Performance Metric:
#
# $$\log \text { Loss }=\frac{-\frac{1}{N_0} \sum_{i=1}^{N_0} y_{0 i} \log p_{0 i}-\frac{1}{N_1} \sum_{i=1}^{N_1} y_{1 i} \log p_{1 i}}{2}$$

# %% [markdown]
# # 1. Import Libraries

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
from keras import metrics
from tensorflow import keras

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import resample

from mlxtend.plotting import scatterplotmatrix
from mlxtend.plotting import heatmap

#improve figure resolution
# %matplotlib inline 
# %config InlineBackend.figure_format = 'retina'


pd.set_option('display.max_columns', None) #show all columns
pd.set_option('display.max_rows', None) #show all rows
# Out:
# 2023-08-09 20:55:42.777321: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print("TensorFlow v" + tf.__version__)
# Out:
# TensorFlow v2.12.0

# %% [markdown]
# # 2. Load Data

# %%
data = pd.read_csv('../icr-identify-age-related-conditions/train.csv')
print("Full train dataset shape is {}".format(data.shape))
# Out:
# Full train dataset shape is (617, 58)

# %% [markdown]
# The data is composed of 58 columns and 617 entries. We can see all 58 dimensions(results will be truncated since the number of columns is big) of our dataset by printing out the first 5 entries using the following code:

# %%
data.head()
# Out:
#              Id        AB          AF          AH         AM        AR  \
# 0  000ff2bfdfe9  0.209377  3109.03329   85.200147  22.394407  8.138688
# 1  007255e47698  0.145282   978.76416   85.200147  36.968889  8.138688
# 2  013f2bd269f5  0.470030  2635.10654   85.200147  32.360553  8.138688
# 3  043ac50845d5  0.252107  3819.65177  120.201618  77.112203  8.138688
# 4  044fb8a146ec  0.380297  3733.04844   85.200147  14.103738  8.138688
#
#          AX        AY         AZ          BC         BD        BN          BP  \
# 0  0.699861  0.025578   9.812214    5.555634  4126.58731  22.5984  175.638726
# 1  3.632190  0.025578  13.517790    1.229900  5496.92824  19.4205  155.868030
# 2  6.732840  0.025578  12.824570    1.229900  5135.78024  26.4825  128.988531
# 3  3.685344  0.025578  11.053708    1.229900  4169.67738  23.6577  237.282264
# %% [markdown]
# # 3. Data Preprocessing

# %% [markdown]
# ### Transform and Split Data

# %%
#convert ej column to one-hot encoding 

ej_dummy = pd.get_dummies(
    data['EJ'],prefix='EJ', dtype=int
)

with_dummies_df = pd.concat(
    [data,ej_dummy],
    axis=1
)

data = with_dummies_df.drop(['EJ'], axis=1)
data.columns
# Out:
# Index(['Id', 'AB', 'AF', 'AH', 'AM', 'AR', 'AX', 'AY', 'AZ', 'BC', 'BD ', 'BN',
#        'BP', 'BQ', 'BR', 'BZ', 'CB', 'CC', 'CD ', 'CF', 'CH', 'CL', 'CR', 'CS',
#        'CU', 'CW ', 'DA', 'DE', 'DF', 'DH', 'DI', 'DL', 'DN', 'DU', 'DV', 'DY',
#        'EB', 'EE', 'EG', 'EH', 'EL', 'EP', 'EU', 'FC', 'FD ', 'FE', 'FI', 'FL',
#        'FR', 'FS', 'GB', 'GE', 'GF', 'GH', 'GI', 'GL', 'Class', 'EJ_A',
#        'EJ_B'],
#       dtype='object')

# %%
#split data on a random 80-20 split
train, test = train_test_split(data, test_size=0.2, random_state = 1234)

# %% [markdown]
# ## Training Preprocessing

# %% [markdown]
# ### Dealing with Class Imbalance

# %%
dist = train['Class'].value_counts()

plt.figure(figsize=(4, 4))
plt.pie(dist, labels=[0,1], autopct='%1.1f%%')
plt.title('Class Labels')
plt.show()

# %% [markdown]
# #### Downsampling
#
# *Removed step in favor of using class weights*

# %%
# # Separate majority and minority classes
# majority_class = train[train['Class'] == 0]
# minority_class = train[train['Class'] == 1]

# # Downsample the majority class to match the size of the minority class
# downsampled_majority = resample(majority_class,
#                                 replace=False,     # Without replacement
#                                 n_samples=len(minority_class),  # Match minority class size
#                                 random_state=42)   # For reproducibility

# # Combine the downsampled majority class with the minority class
# train = pd.concat([downsampled_majority, minority_class])

# # Shuffle the data to avoid any order bias
# train = train.sample(frac=1, random_state=42)

# %% [markdown]
# ### Missing Data

# %%
train_summary = train.describe().transpose()
train_summary.head()
# Out:
#     count         mean          std         min          25%          50%  \
# AB  493.0     0.478481     0.478919    0.081187     0.247834     0.346113
# AF  493.0  3502.936317  2265.358995  192.593280  2255.381920  3186.594290
# AH  493.0   120.512245   141.386037   85.200147    85.200147    85.200147
# AM  493.0    39.414727    71.962273    3.177522    11.957517    20.276059
# AR  493.0    10.174780    11.406413    8.138688     8.138688     8.138688
#
#             75%           max
# AB     0.564036      6.161666
# AF  4348.610530  28688.187660
# AH   108.557685   1910.123198
# AM    37.427245    630.518230
# AR     8.138688    178.943634

# %% [markdown]
# We have 9 columns with missing data, as can be seen below. The columns with the most missing data are BQ and EL, each with 60 null values. Since 60 null values amounts to only about 10% of the dataset, it is reasonable to use imputation to fill the missing values.

# %%
plt.hist(train_summary['count'])
plt.show()
print("Summary of Columns with Missing Data:")
train_summary.loc[train_summary['count'] < 493]
# Out:
# Summary of Columns with Missing Data:
#     count        mean         std        min        25%        50%  \
# BQ  449.0  101.620374   96.797669   1.331155  28.582060  69.024685
# CB  491.0   77.601841  145.155621  12.499760  23.317567  42.673813
# CC  490.0    0.696900    0.280104   0.176874   0.564456   0.663408
# DU  492.0    1.985801   10.051712   0.005518   0.005518   0.237947
# EL  448.0   69.835854   38.627972   5.394675  30.382102  72.309130
# FC  492.0   69.397329  171.759489   7.534128  25.668300  35.394408
# FL  492.0    5.446689   11.449347   0.173229   0.173229   3.000258
# FS  491.0    0.432272    1.449942   0.067730   0.067730   0.250601
# GL  492.0    8.500455   10.310124   0.001129   0.129658   0.339429
#
#            75%          max
# BQ  138.296845   344.644105
# CB   77.082619  1835.203734
# CC    0.776568     4.103032
# DU    1.008686   161.355315
# EL  109.125159   109.125159
# FC   54.443928  3030.655824
# FL    6.186682   137.932739
# FS    0.528294    31.365763
# GL   21.978000    21.978000

# %% [markdown]
# Start with simple imputation which will fill missing values with the mean of the other values recorded for that feature. Note that iterative imputation is also possible through sk learn: https://scikit-learn.org/stable/modules/generated/sklearn.impute.IterativeImputer.html#sklearn.impute.IterativeImputer

# %%
# Identify continuous variables (assuming they are numeric)
continuous_vars = train.select_dtypes(include='number').columns

# Perform mean imputation for continuous variables
train[continuous_vars] = train[continuous_vars].fillna(train[continuous_vars].mean())

# %%
# Check which columns still have missing values 
sum_null = train.isnull().sum()
sum_null[sum_null!=0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ### Split Training Set into X and Y

# %%
columns = train.columns.drop(['Id','Class'])
columns
# Out:
# Index(['AB', 'AF', 'AH', 'AM', 'AR', 'AX', 'AY', 'AZ', 'BC', 'BD ', 'BN', 'BP',
#        'BQ', 'BR', 'BZ', 'CB', 'CC', 'CD ', 'CF', 'CH', 'CL', 'CR', 'CS', 'CU',
#        'CW ', 'DA', 'DE', 'DF', 'DH', 'DI', 'DL', 'DN', 'DU', 'DV', 'DY', 'EB',
#        'EE', 'EG', 'EH', 'EL', 'EP', 'EU', 'FC', 'FD ', 'FE', 'FI', 'FL', 'FR',
#        'FS', 'GB', 'GE', 'GF', 'GH', 'GI', 'GL', 'EJ_A', 'EJ_B'],
#       dtype='object')

# %%
# save x_train, y_train, X_test and Y_test as Numpy arrays
y_train = train['Class'].values
# y_test = test['Class'].values

X_train = train[columns].values
# X_test = test[columns].values


# # Check the shape of the train and test sets
# print('Shape X_train: ', X_train.shape, '\nShape X_test: ', X_test.shape,
#       '\nShape y_train: ', y_train.shape, '\nShape y_test:', y_test.shape)
    
print('Shape X_train: ', X_train.shape,
      '\nShape y_train: ', y_train.shape)
# Out:
# Shape X_train:  (493, 57)
# Shape y_train:  (493,)

# %% [markdown]
# ### Standardize values between 0 and 1

# %%
#normalize all values to be between 0 and 1
# X_train = (X_train-np.min(X_train))/(np.max(X_train)-np.min(X_train))

# #view normalized array
# print(X_train)

# %% [markdown]
# ### Standard Scalar

# %%
# standardize features
sc = StandardScaler()

X_train = sc.fit(X_train).transform(X_train)
# X_test = sc.fit(X_train).transform(X_test)

# %% [markdown]
# # <font color = 'red'> GOD FUCKING DAMNIT THE MODEL IS NO LONGER GOOD IDK NEED TO FIGURE OUT WHY. </font>

# %% [markdown]
# # 4. Model

# %% [markdown]
# Based on Juliana's analysis using Random Forest, we will start by focusing on the following features, in order of importance:
#
# **Suggested features for input:** DU, AB, BQ, GL, CR, DA, DI, AF, CC, EE, FR, DE, EB, DL, CD, FE, DH, BC, FI, EU, BN, BP, CU, CB, DY, FC, DN, AM, EG, CS, GH, CF, GF, BD, GI

# %% [markdown]
# #### Model with Specified Input Features

# %% [markdown]
# An alternative, more flexible option is to use logistic regression, creating an architecutre with a single dense layer and a sigmoid activation function. Logistic regression is very similar to a perceptron but allows us to predict probabilities of binary outcomes as opposed to just a -1 / 1 outcome.

# %%
#create a new array with selected features
feature_list = ['DU', 'AB','BQ','GL','CR','DA','DI','AF','CC','EE','FR',
                'DE','EB','DL','CD ','FE','DH','BC','FI','EU','BN', 'BP',
                'CU', 'CB', 'DY', 'FC', 'DN', 'AM','EG','CS','GH','CF','GF',
                'BD ','GI']
columns = list(columns)
X_limited_train = np.array([])

for feature in feature_list:
    feature_index = columns.index(feature)
    feature_array = X_train[:, feature_index]
    
    if X_limited_train.size == 0:
        X_limited_train = feature_array
    else:
        X_limited_train = np.column_stack((X_limited_train, feature_array))

# %%
def perceptron_tfmodel(num_features, 
                       activation = 'sigmoid', 
                       learning_rate = 0.001, 
                       optimizer = 'SGD'
                       ):
    
    #clear session and set random seed for consistent behavior
    tf.keras.backend.clear_session()
    tf.random.set_seed(1234)
    
    #Build model using Keras Sequential API
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(1, activation = activation, input_shape = (num_features,))
    ])
    
    #set up optimizer
    sgd_optimizer = tf.keras.optimizers.SGD(learning_rate = learning_rate)
    adam_optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate)
    if optimizer == 'Adam':
        optimizer = adam_optimizer
    else:
        optimizer = sgd_optimizer
    
    #compile model
    model.compile(optimizer=optimizer,
                  loss='binary_crossentropy',  # Binary cross-entropy loss for binary classification
                  metrics=['accuracy', tf.keras.metrics.AUC(name='prc', curve='PR')])
    
    return model

# %%
model = perceptron_tfmodel(num_features = X_limited_train.shape[1], learning_rate = 0.05)
# Out:
# Metal device set to: Apple M2
# 2023-08-09 20:55:45.389126: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-08-09 20:55:45.389161: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
#Fit the model
tf.random.set_seed(1234)
np.random.seed(1234)
# Train model
hist= model.fit(x=X_limited_train,
                y=y_train,
                validation_split=0.2, # set 20% of train data for validation
                batch_size= 30, #choose smaller batch size bc we're guessing there are local optima 
                epochs=50,
                verbose=1, #silence fit
                 class_weight = {0: 1.0, 1: 5.0}
)
# Out:
# Epoch 1/50
# 2023-08-09 20:55:45.721622: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 14/14 [==============================] - 1s 37ms/step - loss: 1.4856 - accuracy: 0.5152 - prc: 0.2628 - val_loss: 0.7412 - val_accuracy: 0.5455 - val_prc: 0.3725
# 2023-08-09 20:55:46.278950: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Epoch 2/50
# 14/14 [==============================] - 0s 12ms/step - loss: 1.0100 - accuracy: 0.6548 - prc: 0.5087 - val_loss: 0.6684 - val_accuracy: 0.6162 - val_prc: 0.4928
# Epoch 3/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.8866 - accuracy: 0.6954 - prc: 0.6262 - val_loss: 0.6262 - val_accuracy: 0.6566 - val_prc: 0.5521
# Epoch 4/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.8152 - accuracy: 0.7234 - prc: 0.6782 - val_loss: 0.5878 - val_accuracy: 0.7172 - val_prc: 0.6248
# Epoch 5/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.7674 - accuracy: 0.7640 - prc: 0.7142 - val_loss: 0.5654 - val_accuracy: 0.7273 - val_prc: 0.6719
# Epoch 6/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.7293 - accuracy: 0.7792 - prc: 0.7418 - val_loss: 0.5452 - val_accuracy: 0.7374 - val_prc: 0.7037
# Epoch 7/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.7046 - accuracy: 0.7944 - prc: 0.7526 - val_loss: 0.5230 - val_accuracy: 0.7576 - val_prc: 0.7181
# Epoch 8/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.6865 - accuracy: 0.7970 - prc: 0.7663 - val_loss: 0.5351 - val_accuracy: 0.7576 - val_prc: 0.6953
# Epoch 9/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.6714 - accuracy: 0.8071 - prc: 0.7718 - val_loss: 0.5156 - val_accuracy: 0.7677 - val_prc: 0.7169
# Epoch 10/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.6566 - accuracy: 0.8198 - prc: 0.7767 - val_loss: 0.5035 - val_accuracy: 0.7677 - val_prc: 0.7151
# Epoch 11/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.6464 - accuracy: 0.8325 - prc: 0.7802 - val_loss: 0.4936 - val_accuracy: 0.7677 - val_prc: 0.7301
# Epoch 12/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.6355 - accuracy: 0.8376 - prc: 0.7841 - val_loss: 0.4835 - val_accuracy: 0.7677 - val_prc: 0.7338
# Epoch 13/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.6298 - accuracy: 0.8426 - prc: 0.7864 - val_loss: 0.4727 - val_accuracy: 0.7778 - val_prc: 0.7428
# Epoch 14/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.6199 - accuracy: 0.8376 - prc: 0.7887 - val_loss: 0.4654 - val_accuracy: 0.7778 - val_prc: 0.7408
# Epoch 15/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.6151 - accuracy: 0.8503 - prc: 0.7922 - val_loss: 0.4611 - val_accuracy: 0.7778 - val_prc: 0.7566
# Epoch 16/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.6078 - accuracy: 0.8579 - prc: 0.7937 - val_loss: 0.4787 - val_accuracy: 0.7576 - val_prc: 0.7349
# Epoch 17/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.6025 - accuracy: 0.8503 - prc: 0.7947 - val_loss: 0.4688 - val_accuracy: 0.7778 - val_prc: 0.7522
# Epoch 18/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5959 - accuracy: 0.8553 - prc: 0.7790 - val_loss: 0.4642 - val_accuracy: 0.7778 - val_prc: 0.7535
# Epoch 19/50
# 14/14 [==============================] - 0s 37ms/step - loss: 0.5910 - accuracy: 0.8553 - prc: 0.7810 - val_loss: 0.4605 - val_accuracy: 0.7778 - val_prc: 0.7431
# Epoch 20/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5886 - accuracy: 0.8655 - prc: 0.7962 - val_loss: 0.4590 - val_accuracy: 0.7778 - val_prc: 0.7409
# Epoch 21/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5849 - accuracy: 0.8528 - prc: 0.7823 - val_loss: 0.4650 - val_accuracy: 0.7778 - val_prc: 0.7257
# Epoch 22/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5802 - accuracy: 0.8553 - prc: 0.7832 - val_loss: 0.4602 - val_accuracy: 0.7778 - val_prc: 0.7307
# Epoch 23/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5763 - accuracy: 0.8629 - prc: 0.7980 - val_loss: 0.4598 - val_accuracy: 0.7879 - val_prc: 0.7353
# Epoch 24/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5735 - accuracy: 0.8579 - prc: 0.8017 - val_loss: 0.4588 - val_accuracy: 0.7879 - val_prc: 0.7264
# Epoch 25/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5699 - accuracy: 0.8782 - prc: 0.8006 - val_loss: 0.4536 - val_accuracy: 0.7879 - val_prc: 0.7189
# Epoch 26/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5674 - accuracy: 0.8807 - prc: 0.8018 - val_loss: 0.4481 - val_accuracy: 0.7879 - val_prc: 0.7266
# Epoch 27/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.
50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5270 - accuracy: 0.8807 - prc: 0.8097 - val_loss: 0.4367 - val_accuracy: 0.8182 - val_prc: 0.7243
# Epoch 50/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.5256 - accuracy: 0.8832 - prc: 0.8114 - val_loss: 0.4372 - val_accuracy: 0.8182 - val_prc: 0.7110

# %%
# grab history
history = hist.history

# plot loss for train and validation
fig = plt.figure(figsize=(16, 4))
ax = fig.add_subplot(1, 3, 1)
plt.plot(history['loss'], lw=2, color='darkgoldenrod')
plt.plot(history['val_loss'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
ax.set_xlabel('Epochs', size=10)
ax.set_title('Loss');

# plot accuracy for train and validation
ax = fig.add_subplot(1, 3, 2)
plt.plot(history['prc'], lw=2, color='darkgoldenrod')
plt.plot(history['val_prc'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
ax.set_xlabel('Epochs', size=10)
ax.set_title('AUC-PRC');

# plot accuracy for train and validation
ax = fig.add_subplot(1, 3, 3)
plt.plot(history['accuracy'], lw=2, color='darkgoldenrod')
plt.plot(history['val_accuracy'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
ax.set_xlabel('Epochs', size=10)
ax.set_title('Accuracy');

plt.show()

print('\nBaseline:          %1.4f' %(np.count_nonzero(y_train == 0)/len(y_train)))
print('Train Accuracy:     %1.4f' %(history['accuracy'][-1]))
print('AUC-PRC:           %1.4f' %(history['prc'][-1]))
# Out:
# Baseline:          0.8134
# Train Accuracy:     0.8832
# AUC-PRC:           0.8114

# %% [markdown]
# #### Model with all input features

# %%
model = perceptron_tfmodel(num_features = X_train.shape[1], learning_rate = 0.05)

# %%
#Fit the model
tf.random.set_seed(1234)
np.random.seed(1234)
# Train model
hist= model.fit(x=X_train,
                y=y_train,
                validation_split=0.2, # set 20% of train data for validation
                batch_size= 30, #choose smaller batch size bc we're guessing there are local optima 
                epochs=50,
                verbose=1, #silence fit
                class_weight = {0: 1.0, 1: 5.0}
)
# Out:
# Epoch 1/50
#  8/14 [================>.............] - ETA: 0s - loss: 1.0112 - accuracy: 0.6542 - prc: 0.5883
# 2023-08-09 20:56:20.193888: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 14/14 [==============================] - 1s 32ms/step - loss: 1.0746 - accuracy: 0.6523 - prc: 0.5544 - val_loss: 0.7830 - val_accuracy: 0.6566 - val_prc: 0.3438
# Epoch 2/50
#  1/14 [=>............................] - ETA: 0s - loss: 0.9716 - accuracy: 0.7000 - prc: 0.7795
# 2023-08-09 20:56:20.590985: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 14/14 [==============================] - 0s 13ms/step - loss: 0.8919 - accuracy: 0.6929 - prc: 0.6457 - val_loss: 0.7324 - val_accuracy: 0.6768 - val_prc: 0.4202
# Epoch 3/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.8102 - accuracy: 0.7310 - prc: 0.6905 - val_loss: 0.6885 - val_accuracy: 0.6869 - val_prc: 0.4833
# Epoch 4/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.7530 - accuracy: 0.7716 - prc: 0.7306 - val_loss: 0.6355 - val_accuracy: 0.6869 - val_prc: 0.5194
# Epoch 5/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.7084 - accuracy: 0.7893 - prc: 0.7546 - val_loss: 0.6060 - val_accuracy: 0.7071 - val_prc: 0.5590
# Epoch 6/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.6714 - accuracy: 0.7995 - prc: 0.7816 - val_loss: 0.5679 - val_accuracy: 0.7172 - val_prc: 0.5906
# Epoch 7/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.
50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4793 - accuracy: 0.8959 - prc: 0.8513 - val_loss: 0.4009 - val_accuracy: 0.8384 - val_prc: 0.7531
# Epoch 30/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4837 - accuracy: 0.9036 - prc: 0.8537 - val_loss: 0.3965 - val_accuracy: 0.8182 - val_prc: 0.7625
# Epoch 31/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4772 - accuracy: 0.9036 - prc: 0.8503 - val_loss: 0.3916 - val_accuracy: 0.8485 - val_prc: 0.7554
# Epoch 32/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4732 - accuracy: 0.9061 - prc: 0.8521 - val_loss: 0.4111 - val_accuracy: 0.8182 - val_prc: 0.7272
# Epoch 33/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4770 - accuracy: 0.9086 - prc: 0.8513 - val_loss: 0.4214 - val_accuracy: 0.7980 - val_prc: 0.7280
# Epoch 34/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4738 - accuracy: 0.9036 - prc: 0.8522 - val_loss: 0.4177 - val_accuracy: 0.7980 - val_prc: 0.7284
# Epoch 35/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4697 - accuracy: 0.8985 - prc: 0.8506 - val_loss: 0.4137 - val_accuracy: 0.8081 - val_prc: 0.7342
# Epoch 36/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4668 - accuracy: 0.9086 - prc: 0.8557 - val_loss: 0.4139 - val_accuracy: 0.8081 - val_prc: 0.7335
# Epoch 37/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4644 - accuracy: 0.9086 - prc: 0.8507 - val_loss: 0.4085 - val_accuracy: 0.8081 - val_prc: 0.7377
# Epoch 38/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4620 - accuracy: 0.9061 - prc: 0.8513 - val_loss: 0.4091 - val_accuracy: 0.8283 - val_prc: 0.7441
# Epoch 39/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4635 - accuracy: 0.9010 - prc: 0.8541 - val_loss: 0.4077 - val_accuracy: 0.8283 - val_prc: 0.7434
# Epoch 40/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4590 - accuracy: 0.8959 - prc: 0.8555 - val_loss: 0.4055 - val_accuracy: 0.8283 - val_prc: 0.7370
# Epoch 41/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4561 - accuracy: 0.9010 - prc: 0.8540 - val_loss: 0.4057 - val_accuracy: 0.8283 - val_prc: 0.7437
# Epoch 42/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4554 - accuracy: 0.9010 - prc: 0.8535 - val_loss: 0.3949 - val_accuracy: 0.8283 - val_prc: 0.7481
# Epoch 43/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4573 - accuracy: 0.9086 - prc: 0.8555 - val_loss: 0.3883 - val_accuracy: 0.8384 - val_prc: 0.7644
# Epoch 44/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4538 - accuracy: 0.9036 - prc: 0.8543 - val_loss: 0.3880 - val_accuracy: 0.8283 - val_prc: 0.7576
# Epoch 45/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4529 - accuracy: 0.9010 - prc: 0.8547 - val_loss: 0.3849 - val_accuracy: 0.8384 - val_prc: 0.7663
# Epoch 46/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4502 - accuracy: 0.9086 - prc: 0.8582 - val_loss: 0.3907 - val_accuracy: 0.8283 - val_prc: 0.7534
# Epoch 47/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4485 - accuracy: 0.9061 - prc: 0.8573 - val_loss: 0.3988 - val_accuracy: 0.8283 - val_prc: 0.7472
# Epoch 48/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.4501 - accuracy: 0.9036 - prc: 0.8564 - val_loss: 0.3989 - val_accuracy: 0.8283 - val_prc: 0.7463
# Epoch 49/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.4482 - accuracy: 0.9061 - prc: 0.8543 - val_loss: 0.4036 - val_accuracy: 0.8283 - val_prc: 0.7433
# Epoch 50/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.4458 - accuracy: 0.9086 - prc: 0.8558 - val_loss: 0.4015 - val_accuracy: 0.8081 - val_prc: 0.7428

# %%
# grab history
history = hist.history

# plot loss for train and validation
fig = plt.figure(figsize=(16, 4))
ax = fig.add_subplot(1, 3, 1)
plt.plot(history['loss'], lw=2, color='darkgoldenrod')
plt.plot(history['val_loss'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
ax.set_xlabel('Epochs', size=10)
ax.set_title('Loss');

# plot accuracy for train and validation
ax = fig.add_subplot(1, 3, 2)
plt.plot(history['prc'], lw=2, color='darkgoldenrod')
plt.plot(history['val_prc'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
ax.set_xlabel('Epochs', size=10)
ax.set_title('AUC-PRC');

# plot accuracy for train and validation
ax = fig.add_subplot(1, 3, 3)
plt.plot(history['accuracy'], lw=2, color='darkgoldenrod')
plt.plot(history['val_accuracy'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
ax.set_xlabel('Epochs', size=10)
ax.set_title('Accuracy');

plt.show()

print('\nBaseline:          %1.4f' %(np.count_nonzero(y_train == 0)/len(y_train)))
print('Train Accuracy:     %1.4f' %(history['accuracy'][-1]))
print('AUC-PRC:           %1.4f' %(history['prc'][-1]))
# Out:
# Baseline:          0.8134
# Train Accuracy:     0.9086
# AUC-PRC:           0.8558

# %% [markdown]
# **Conclusion:** Logistic regression is far better than the basic perceptron. The full number of features provide better performance.

# %% [markdown]
# # Test

# %% [markdown]
# ### Test Preprocessing

# %%
def balanced_log_loss(y_true, y_pred):
    N0 = np.sum(y_true == 0) #num observations class 0
    N1 = np.sum(y_true == 1) #num observations class 1

    p0 = y_pred[y_true == 0] #pred_prob class 0
    p1 = y_pred[y_true == 1] #pred_prob class 0

    y0 = y_true[y_true == 0] #ground truth class 0
    y1 = y_true[y_true == 1] #ground truth class 1

    log_loss_0 = np.sum(y0 * np.log(np.clip(p0, 1e-15, 1.0))) / N0 if N0 > 0 else 0 #balanced log loss class 0, adjust for edge cases (removed the negative sign to avoid negative log loss)
    log_loss_1 = np.sum(y1 * np.log(np.clip(p1, 1e-15, 1.0))) / N1 if N1 > 0 else 0 #balanced log loss class 1, adjust for edge cases 

    return (log_loss_0 + log_loss_1) / 2

# %%
dist = test['Class'].value_counts()

plt.figure(figsize=(4, 4))
plt.pie(dist, labels=[0,1], autopct='%1.1f%%')
plt.title('Class Labels')
plt.show()

# %%
test_summary = test.describe().transpose()
test_summary.head()
# Out:
#     count         mean          std         min          25%          50%  \
# AB  124.0     0.471856     0.425713    0.085460     0.272404     0.371751
# AF  124.0  3498.343169  2443.976416  192.593280  1904.585073  2938.594505
# AH  124.0   111.119255    42.611482   85.200147    85.200147    85.200147
# AM  124.0    37.194645    60.261192    4.803447    14.037927    22.434668
# AR  124.0     9.943216     5.802178    8.138688     8.138688     8.138688
#
#             75%           max
# AB     0.548012      4.277273
# AF  4449.890252  18720.829600
# AH   128.760388    292.021479
# AM    47.651216    630.518230
# AR     8.293386     59.390922

# %%
# Identify continuous variables (assuming they are numeric)
continuous_vars = test.select_dtypes(include='number').columns

# Perform mean imputation for continuous variables
test[continuous_vars] = test[continuous_vars].fillna(test[continuous_vars].mean())

# %%
# save X_test and Y_test as Numpy arrays

y_test = test['Class'].values
X_test = test[columns].values

# Check the shape of the test sets
    
print('Shape X_test: ', X_test.shape,
      '\nShape y_test: ', y_test.shape)
# Out:
# Shape X_test:  (124, 57)
# Shape y_test:  (124,)

# %%
# standardize features
sc = StandardScaler()

X_test = sc.fit(X_test).transform(X_test)

# %%
#limit the features

X_limited_test = np.array([])

for feature in feature_list:
    feature_index = columns.index(feature)
    feature_array = X_test[:, feature_index]
    
    if X_limited_test.size == 0:
        X_limited_test = feature_array
    else:
        X_limited_test = np.column_stack((X_limited_test, feature_array))

# %% [markdown]
# ### Train the Chosen Model

# %%
model = perceptron_tfmodel(num_features = X_train.shape[1], learning_rate = 0.05)

# %%
#Fit the model
tf.random.set_seed(1234)
np.random.seed(1234)
# Train model
hist= model.fit(x=X_train,
                y=y_train,
                validation_split=0.2, # set 20% of train data for validation
                batch_size= 30, #choose smaller batch size bc we're guessing there are local optima 
                epochs=50,
                verbose=1, #silence fit
                 class_weight = {0: 1.0, 1: 5.0}
)
# Out:
# Epoch 1/50
#  8/14 [================>.............] - ETA: 0s - loss: 1.2327 - accuracy: 0.5833 - prc: 0.3087
# 2023-08-09 20:58:49.875552: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 14/14 [==============================] - 1s 32ms/step - loss: 1.1804 - accuracy: 0.5990 - prc: 0.3567 - val_loss: 0.7167 - val_accuracy: 0.5960 - val_prc: 0.4089
# Epoch 2/50
#  1/14 [=>............................] - ETA: 0s - loss: 0.8209 - accuracy: 0.6000 - prc: 0.8274
# 2023-08-09 20:58:50.264759: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 14/14 [==============================] - 0s 14ms/step - loss: 0.8503 - accuracy: 0.6904 - prc: 0.6301 - val_loss: 0.6503 - val_accuracy: 0.6263 - val_prc: 0.5668
# Epoch 3/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.7705 - accuracy: 0.7310 - prc: 0.6962 - val_loss: 0.6054 - val_accuracy: 0.6970 - val_prc: 0.6303
# Epoch 4/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.7172 - accuracy: 0.7690 - prc: 0.7363 - val_loss: 0.5649 - val_accuracy: 0.6970 - val_prc: 0.6611
# Epoch 5/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.6815 - accuracy: 0.8020 - prc: 0.7552 - val_loss: 0.5427 - val_accuracy: 0.7071 - val_prc: 0.7139
# Epoch 6/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.6573 - accuracy: 0.8096 - prc: 0.7673 - val_loss: 0.5186 - val_accuracy: 0.7374 - val_prc: 0.7215
# Epoch 7/50
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6363 - accuracy: 0.8198 - prc: 0.7797 - val_loss: 0.4883 - val_accuracy: 0.7677 - val_prc: 0.7550
# Epoch 8/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.6274 - accuracy: 0.8401 - prc: 0.7859 - val_loss: 0.4935 - val_accuracy: 0.7677 - val_prc: 0.7341
# Epoch 9/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.6095 - accuracy: 0.8452 - prc: 0.7933 - val_loss: 0.4714 - val_accuracy: 0.7980 - val_prc: 0.7460
# Epoch 10/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5948 - accuracy: 0.8680 - prc: 0.7968 - val_loss: 0.4640 - val_accuracy: 0.7980 - val_prc: 0.7355
# Epoch 11/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.5872 - accuracy: 0.8706 - prc: 0.8008 - val_loss: 0.4586 - val_accuracy: 0.8081 - val_prc: 0.7216
# Epoch 12/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.5738 - accuracy: 0.8706 - prc: 0.8035 - val_loss: 0.4495 - val_accuracy: 0.7980 - val_prc: 0.7298
# Epoch 13/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.5696 - accuracy: 0.8731 - prc: 0.8010 - val_loss: 0.4428 - val_accuracy: 0.8182 - val_prc: 0.7342
# Epoch 14/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.5599 - accuracy: 0.8756 - prc: 0.8067 - val_loss: 0.4374 - val_accuracy: 0.8384 - val_prc: 0.7166
# Epoch 15/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.5541 - accuracy: 0.8832 - prc: 0.8072 - val_loss: 0.4300 - val_accuracy: 0.8485 - val_prc: 0.7227
# Epoch 16/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.5469 - accuracy: 0.8883 - prc: 0.8083 - val_loss: 0.4612 - val_accuracy: 0.8182 - val_prc: 0.7217
# Epoch 17/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.5432 - accuracy: 0.8807 - prc: 0.8058 - val_loss: 0.4404 - val_accuracy: 0.8384 - val_prc: 0.7245
# Epoch 18/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5366 - accuracy: 0.8832 - prc: 0.8073 - val_loss: 0.4392 - val_accuracy: 0.8384 - val_prc: 0.7235
# Epoch 19/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.5303 - accuracy: 0.8883 - prc: 0.8091 - val_loss: 0.4327 - val_accuracy: 0.8384 - val_prc: 0.7162
# Epoch 20/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.5305 - accuracy: 0.8909 - prc: 0.8113 - val_loss: 0.4349 - val_accuracy: 0.8283 - val_prc: 0.7301
# Epoch 21/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.5254 - accuracy: 0.8883 - prc: 0.8116 - val_loss: 0.4400 - val_accuracy: 0.8283 - val_prc: 0.7159
# Epoch 22/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.5186 - accuracy: 0.8909 - prc: 0.8149 - val_loss: 0.4320 - val_accuracy: 0.8283 - val_prc: 0.7190
# Epoch 23/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5150 - accuracy: 0.8883 - prc: 0.8172 - val_loss: 0.4342 - val_accuracy: 0.8283 - val_prc: 0.7226
# Epoch 24/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.5114 - accuracy: 0.8858 - prc: 0.8195 - val_loss: 0.4326 - val_accuracy: 0.8283 - val_prc: 0.7176
# Epoch 25/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5081 - accuracy: 0.9010 - prc: 0.8199 - val_loss: 0.4289 - val_accuracy: 0.8283 - val_prc: 0.7081
# Epoch 26/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.5059 - accuracy: 0.8934 - prc: 0.8194 - val_loss: 0.4226 - val_accuracy: 0.8283 - val_prc: 0.7193
# Epoch 27/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.5026 - accuracy: 0.8959 - prc: 0.8216 - val_loss: 0.4202 - val_accuracy: 0.8283 - val_prc: 0.7224
# Epoch 28/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4991 - accuracy: 0.8909 - prc: 0.8222 - val_loss: 0.4145 - val_accuracy: 0.8283 - val_prc: 0.7190
# Epoch 29/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4964 - accuracy: 0.8959 - prc: 0.8221 - val_loss: 0.4150 - val_accuracy: 0.8485 - val_prc: 0.7394
# Epoch 30/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5005 - accuracy: 0.8959 - prc: 0.8385 - val_loss: 0.4069 - val_accuracy: 0.8485 - val_prc: 0.7411
# Epoch 31/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4935 - accuracy: 0.8934 - prc: 0.8201 - val_loss: 0.4032 - val_accuracy: 0.8485 - val_prc: 0.7396
# Epoch 32/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4892 - accuracy: 0.8934 - prc: 0.8228 - val_loss: 0.4236 - val_accuracy: 0.8485 - val_prc: 0.6952
# Epoch 33/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4932 - accuracy: 0.8985 - prc: 0.8369 - val_loss: 0.4337 - val_accuracy: 0.8081 - val_prc: 0.6921
# Epoch 34/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4897 - accuracy: 0.8959 - prc: 0.8390 - val_loss: 0.4281 - val_accuracy: 0.8384 - val_prc: 0.7122
# Epoch 35/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4850 - accuracy: 0.8909 - prc: 0.8397 - val_loss: 0.4240 - val_accuracy: 0.8182 - val_prc: 0.7051
# Epoch 36/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4821 - accuracy: 0.8934 - prc: 0.8417 - val_loss: 0.4233 - val_accuracy: 0.8283 - val_prc: 0.7144
# Epoch 37/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4795 - accuracy: 0.9010 - prc: 0.8408 - val_loss: 0.4185 - val_accuracy: 0.8283 - val_prc: 0.7258
# Epoch 38/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4767 - accuracy: 0.8959 - prc: 0.8441 - val_loss: 0.4207 - val_accuracy: 0.8283 - val_prc: 0.7199
# Epoch 39/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4789 - accuracy: 0.8883 - prc: 0.8423 - val_loss: 0.4173 - val_accuracy: 0.8182 - val_prc: 0.7289
# Epoch 40/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4735 - accuracy: 0.8858 - prc: 0.8423 - val_loss: 0.4142 - val_accuracy: 0.8182 - val_prc: 0.7226
# Epoch 41/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4702 - accuracy: 0.8858 - prc: 0.8442 - val_loss: 0.4147 - val_accuracy: 0.8182 - val_prc: 0.7245
# Epoch 42/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4694 - accuracy: 0.8883 - prc: 0.8418 - val_loss: 0.4048 - val_accuracy: 0.8384 - val_prc: 0.7275
# Epoch 43/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4713 - accuracy: 0.8959 - prc: 0.8439 - val_loss: 0.3973 - val_accuracy: 0.8283 - val_prc: 0.7525
# Epoch 44/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4675 - accuracy: 0.8909 - prc: 0.8458 - val_loss: 0.3968 - val_accuracy: 0.8283 - val_prc: 0.7478
# Epoch 45/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4664 - accuracy: 0.8985 - prc: 0.8469 - val_loss: 0.3936 - val_accuracy: 0.8384 - val_prc: 0.7518
# Epoch 46/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4634 - accuracy: 0.8985 - prc: 0.8481 - val_loss: 0.3987 - val_accuracy: 0.8384 - val_prc: 0.7402
# Epoch 47/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4614 - accuracy: 0.9010 - prc: 0.8511 - val_loss: 0.4066 - val_accuracy: 0.8384 - val_prc: 0.7388
# Epoch 48/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4630 - accuracy: 0.9010 - prc: 0.8472 - val_loss: 0.4066 - val_accuracy: 0.8384 - val_prc: 0.7395
# Epoch 49/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4609 - accuracy: 0.8934 - prc: 0.8475 - val_loss: 0.4125 - val_accuracy: 0.8283 - val_prc: 0.7287
# Epoch 50/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4583 - accuracy: 0.9010 - prc: 0.8488 - val_loss: 0.4091 - val_accuracy: 0.8283 - val_prc: 0.7293

# %% [markdown]
# ### Test the model

# %%
model_eval = model.evaluate(x=X_test, y=y_test,
                                verbose=0, return_dict=True)

y_test_pred = model.predict(x=X_test, verbose=0)

print('\nBaseline:          %1.4f' %(np.count_nonzero(y_test == 0)/len(y_test)))
print('Test Accuracy:     %1.4f' %(model_eval['accuracy']))
print('\nAUC-PRC:           %1.4f' %(model_eval['prc']))
print('Balanced Log Loss: %1.4f' %(balanced_log_loss(y_test, y_test_pred)))
# Out:
# Baseline:          0.8710
# Test Accuracy:     0.8226
#
# AUC-PRC:           0.5503
# Balanced Log Loss: -1.2092

# %% [markdown]
# **Conclusion:** Not great performance on the test set...
